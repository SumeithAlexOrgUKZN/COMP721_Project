# %% [markdown]
# # UKZN COMP721 Project
#
# ## Sumeith Ishwanthlal (219006284)
# ## Alexander Goudemond (219030365)
#
# # Determining a suitable benchmark
#
#
# - 3 Point Field Goals Attempted
# - 3 Point Field Goals Made
# - Assists
# - Blocks
# - Defensive Rebounds
# - Field Goals Attempted
# - Field Goals Made
# - Free Throws Attempted
# - Free Throws Made
# - Offensive Rebounds
# - Personal Fouls
# - Points
# - Rebounds
# - Steals
# - Turnover
#
#
#
# - 3 Point Field Goals Attempted
# - 3 Point Field Goals Made
# - Assists
# - Blocks
# - Defensive Rebounds
# - Field Goals Attempted
# - Field Goals Made
# - Free Throws Attempted
# - Free Throws Made
# - Offensive Rebounds
# - Personal Fouls
# - Points
# - Rebounds
# - Steals
# - Turnover

# %%
import pandas as pd

# %%
df = pd.read_csv('databasebasketball/team_season.txt')

# %%
df
# Out:
#      team  year leag  o_fgm  o_fga  o_ftm  o_fta  o_oreb  o_dreb  o_reb  ...  \
# 0     BOS  1946    N   1397   5133    811   1375       0       0      0  ...
# 1     CH1  1946    N   1879   6309    939   1550       0       0      0  ...
# 2     CL1  1946    N   1674   5699    903   1428       0       0      0  ...
# 3     DE1  1946    N   1437   5843    923   1494       0       0      0  ...
# 4     NYK  1946    N   1465   5255    951   1438       0       0      0  ...
# ...   ...   ...  ...    ...    ...    ...    ...     ...     ...    ...  ...
# 1182  SAS  2004    N   2923   6450   1535   2120     987    2489   3476  ...
# 1183  SEA  2004    N   2882   6498   1683   2131    1041    2311   3352  ...
# 1184  TOR  2004    N   2952   6656   1626   2101     844    2444   3288  ...
# 1185  UTA  2004    N   2828   6301   1719   2272    1047    2243   3290  ...
# 1186  WAS  2004    N   2966   6794   1795   2476    1133    2374   3507  ...
#
# ...

# %%
df.columns
# Out:
# Index(['team', 'year', 'leag', 'o_fgm', 'o_fga', 'o_ftm', 'o_fta', 'o_oreb',
#        'o_dreb', 'o_reb', 'o_asts', 'o_pf', 'o_stl', 'o_to', 'o_blk', 'o_3pm',
#        'o_3pa', 'o_pts', 'd_fgm', 'd_fga', 'd_ftm', 'd_fta', 'd_oreb',
#        'd_dreb', 'd_reb', 'd_asts', 'd_pf', 'd_stl', 'd_to', 'd_blk', 'd_3pm',
#        'd_3pa', 'd_pts', 'pace', 'won', 'lost'],
#       dtype='object')

# %%
df.drop(["team", "year", "leag", "pace", "won", "lost"], axis = 1, inplace = True)

# %%
df["defensive"] = df["d_3pa"] + df["d_3pm"] + df["d_asts"] + df["d_blk"] + df["d_dreb"] + df["d_fga"] + df["d_fgm"] + df["d_fta"] + df["d_ftm"] + df["d_oreb"] - df["d_pf"] + df["d_pts"] + df["d_reb"] + df["d_stl"] + df["d_to"]
df["offensive"] = df["o_3pa"] + df["o_3pm"] + df["o_asts"] + df["o_blk"] + df["o_dreb"] + df["o_fga"] + df["o_fgm"] + df["o_fta"] + df["o_ftm"] + df["o_oreb"] - df["o_pf"] + df["o_pts"] + df["o_reb"] + df["o_stl"] + df["o_to"]

df[] = def []

# %%
df["ratio_offensive"] = df["offensive"] / (df["offensive"] + df["defensive"])
df["ratio_defensive"] = df["defensive"] / (df["offensive"] + df["defensive"])

# %%
df
# Out:
#       o_fgm  o_fga  o_ftm  o_fta  o_oreb  o_dreb  o_reb  o_asts  o_pf  o_stl  \
# 0      1397   5133    811   1375       0       0      0     470  1202      0
# 1      1879   6309    939   1550       0       0      0     436  1473      0
# 2      1674   5699    903   1428       0       0      0     494  1246      0
# 3      1437   5843    923   1494       0       0      0     482  1351      0
# 4      1465   5255    951   1438       0       0      0     457  1218      0
# ...     ...    ...    ...    ...     ...     ...    ...     ...   ...    ...
# 1182   2923   6450   1535   2120     987    2489   3476    1771  1716    613
# 1183   2882   6498   1683   2131    1041    2311   3352    1487  1943    553
# 1184   2952   6656   1626   2101     844    2444   3288    1670  1875    621
# 1185   2828   6301   1719   2272    1047    2243   3290    1826  2189    541
# 1186   2966   6794   1795   2476    1133    2374   3507    1563  1806    716
#
# ...

# %%
quantileDf = df.quantile([0, 0.25, .5, 0.75, 1], interpolation="nearest")

# %%
quantileDf
# Out:
#       o_fgm  o_fga  o_ftm  o_fta  o_oreb  o_dreb  o_reb  o_asts  o_pf  o_stl  \
# 0.00    432   1020    217    278       0       0      0     215   253      0
# 0.25   2964   6633   1540   2070       0       0   3425    1704  1800      0
# 0.50   3349   7148   1711   2288    1016    2341   3628    1899  1940    629
# 0.75   3557   7639   1917   2542    1159    2481   3990    2071  2073    720
# 1.00   4059   9295   2607   3434    1520    3074   6131    2575  2470   1059
#
#       ...  d_to  d_blk  d_3pm  d_3pa  d_pts  defensive  offensive     ratio  \
# 0.00  ...     0      0      0      0   1138       3010       3552  0.881732
# 0.25  ...     0      0      0      0   7914      27949      29841  0.981740
# 0.50  ...  1222    376     96      0   8583      31756      31790  1.014092
# 0.75  ...  1417    439    286      0   9037      33444      33467  1.062060
# 1.00  ...  1980    654    613   1560  10723      40475      37350  3.814180
#
#       ratio_offensive  ratio_defensive
# ...

# %%
type(df.quantile([0, 0.25, .5, 0.75, 1], interpolation="nearest"))
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.quantile([0, 0.25, .5, 0.75, 1], interpolation="nearest"))
# Out:
# pandas.core.frame.DataFrame

# %%
t1 = df["o_fta"].sum()
t2 = df["o_dreb"].sum()

# %%
t1/t2
# Out:
# 1.4110683885009634

# %%
df[-31:]
# Out:
#      team  year leag  o_fgm  o_fga  o_ftm  o_fta  o_oreb  o_dreb  o_reb  ...  \
# 1156  WAS  2003    N   2758   6556   1579   2211    1115    2392   3507  ...
# 1157  ATL  2004    N   2942   6672   1417   1994    1100    2335   3435  ...
# 1158  BOS  2004    N   3046   6511   1775   2323     909    2438   3347  ...
# 1159  CHI  2004    N   2849   6592   1536   2048    1001    2591   3592  ...
# 1160  CHR  2004    N   2961   6859   1487   2096    1083    2335   3418  ...
# 1161  CLE  2004    N   2990   6687   1634   2174    1117    2352   3469  ...
# 1162  DAL  2004    N   3058   6691   1826   2314     990    2530   3520  ...
# 1163  DEN  2004    N   3038   6615   1765   2313     967    2473   3440  ...
# 1164  DET  2004    N   2851   6421   1588   2150    1054    2507   3561  ...
# 1165  GSW  2004    N   3029   7039   1412   1955    1069    2436   3505  ...
# 1166  HOU  2004    N   2846   6419   1551   1986     874    2601   3475  ...
# ...

# %%
len(pd.unique(df["team"]))
# Out:
# 91

# %%
pd.unique(df["year"])
# Out:
# array([1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004], dtype=int64)
